# %% [markdown]
# ## Practice : People detector and analyzer
#
# 1. Input images from wiiplay.mp4 with frame number between 41000 and 44000.
# 2. Use YOLOv8 to detect people, mark as red rectangle, and count how many persons in each frame. (hint: check label == 'person')
# 3. Try to find out which frame contains the most number of persons. (print the number of persons on the upper-left corner)
# 4. (optional) Try to find out which frame containes the largest person. (print the size of its bounding box on the upper-left corner)
# 5. (optional) Try to find out which frame containes the smallest person. (print the size of its bounding box on the upper-left corner)
# 6. Show the three output frames you found.
# 7. Verify the correctness of your output, then adjust the desired confidence threshold for improvement.
# 8. Upload your Jupyter code file (*.ipynb)

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
# load the video
cap = cv2.VideoCapture('WiiPlay.mp4')

# Initialize variables to store the frame number with the most people, the number of people in that frame

most_people_frame = None
most_people_count = 0

largest_person_frame = None
largest_person_size = 0

smallest_person_frame = None
smallest_person_size = float('inf')

# Set the start and end frame
start_frame = 41000
end_frame = 44000

current_frame_number = start_frame

cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

while True:
    # Read the frame
    ret, img = cap.read()
    if not ret or current_frame_number > end_frame:
        break

    current_frame_number += 1
    
    # Flip the image horizontally
    img = cv2.flip(img, 1)

    # Load the image to the YOLOv8 model
    results = model.predict(img, conf=0.1119)

    # Init variables to store the number of persons, the largest and smallest person size
    person_count = 0
    frame_largest_size = 0
    frame_smallest_size = float('inf')

    # Init list to store the bounding boxes
    bounding_boxes = []

    # Loop through the results and draw the bounding boxes on the image.
    
    for result in results:
        for box in result.boxes:
            label = results[0].names[int(box.cls)]

            # If the label is person, draw the bounding box
            if label == 'person':
                person_count += 1

                # Get the bounding box coordinates
                left, top, right, bottom = np.array(box.xyxy.cpu(), dtype=np.uint16).squeeze()

                """
                Calculate the width, height, and size of the bounding box.
                Append the bounding box coordinates and size to the bounding_boxes list.
                Update the frame_largest_size and frame_smallest_size if needed.
                """
                width = right - left
                height = bottom - top
                size = width * height
                bounding_boxes.append((left, top, width, height, size))

                # Update the frame_largest_size and frame_smallest_size

                if size > frame_largest_size:
                    frame_largest_size = size
                if size < frame_smallest_size:
                    frame_smallest_size = size

                # Draw the bounding box and label
                cv2.rectangle(img, (left, top), (right, bottom), (0, 255, 0), 2)

                # Add the confidence to the label
                confidence = float(box.conf.cpu())

                # Add the label to the bounding box
                cv2.putText(img, label, (left, top - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36, 255, 12), 2)
            
    # Update most people count frame
    if person_count > most_people_count:
        most_people_count = person_count
        most_people_frame = current_frame_number

    # Update largest person frame
    if frame_largest_size > largest_person_size:
        largest_person_size = frame_largest_size
        largest_person_frame = current_frame_number

    # Update smallest person frame
    if frame_smallest_size < smallest_person_size:
        smallest_person_size = frame_smallest_size
        smallest_person_frame = current_frame_number

    # Print the number of persons on the upper-left corner
    cv2.putText(img, f'Persons: {person_count}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Print the size of each bounding box on the upper-left corner
    for i, (left, top, width, height, size) in enumerate(bounding_boxes):
        cv2.putText(img, f'Size {i+1}: {size}', (10, 60 + i * 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    text = f'Current_Frame: {current_frame_number}'

    # get the size of the text
    text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 1, 2)[0]

    # 10 pixels from the right edge
    text_x = img.shape[1] - text_size[0] - 10 

    # 30 pixels from the top edge
    text_y = 30

    # Print the frame number on the upper-right corner 
    cv2.putText(img, text, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Show the image
    cv2.imshow('Result', img)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close the windows
cap.release()
cv2.destroyAllWindows()

"""
Print the frame number with the most people, the number of people in that frame,
the frame number with the largest person, the size of the largest person,
the frame number with the smallest person, and the size of the smallest person.
"""

print(f'Most people in frame: {most_people_frame} with {most_people_count} persons')
print(f'Largest person in frame: {largest_person_frame} with size {largest_person_size}')
print(f'Smallest person in frame: {smallest_person_frame} with size {smallest_person_size}')
# Out:
# 0: 384x640 29 persons, 27.4ms
# Speed: 11.9ms preprocess, 27.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 fire hydrant, 27.1ms
# Speed: 3.1ms preprocess, 27.1ms inference, 18.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 28.2ms
# Speed: 3.8ms preprocess, 28.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 24.6ms
# Speed: 3.7ms preprocess, 24.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 teddy bears, 26.2ms
# Speed: 3.0ms preprocess, 26.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 teddy bears, 24.7ms
# Speed: 2.7ms preprocess, 24.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 teddy bears, 24.3ms
# Speed: 2.9ms preprocess, 24.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 3 teddy bears, 24.5ms
# Speed: 2.9ms preprocess, 24.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 1 teddy bear, 24.6ms
# Speed: 3.3ms preprocess, 24.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 4 teddy bears, 23.7ms
# Speed: 2.5ms preprocess, 23.7ms inference, 19.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 train, 68.5ms
# Speed: 9.0ms preprocess, 68.5ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 32.8ms
# Speed: 6.0ms preprocess, 32.8ms inference, 18.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 teddy bear, 108.3ms
# Speed: 19.3ms preprocess, 108.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 24.1ms
# Speed: 2.9ms preprocess, 24.1ms inference, 15.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 traffic light, 3 teddy bears, 89.2ms
# Speed: 6.0ms preprocess, 89.2ms inference, 22.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 traffic light, 1 teddy bear, 23.5ms
# Speed: 4.9ms preprocess, 23.5ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 teddy bears, 100.1ms
# Speed: 16.9ms preprocess, 100.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 24.0ms
# Speed: 3.2ms preprocess, 24.0ms inference, 18.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 23.5ms
# Speed: 4.1ms preprocess, 23.5ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 teddy bears, 80.7ms
# Speed: 16.0ms preprocess, 80.7ms inference, 25.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 teddy bears, 47.4ms
# Speed: 6.9ms preprocess, 47.4ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 fire hydrant, 2 teddy bears, 30.5ms
# Speed: 6.1ms preprocess, 30.5ms inference, 26.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 fire hydrants, 7 teddy bears, 101.2ms
# Speed: 16.2ms preprocess, 101.2ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 3 teddy bears, 28.1ms
# Speed: 4.6ms preprocess, 28.1ms inference, 15.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 traffic light, 1 teddy bear, 73.5ms
# Speed: 18.4ms preprocess, 73.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 31.3ms
# Speed: 5.7ms preprocess, 31.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 116.0ms
# Speed: 19.6ms preprocess, 116.0ms inference, 25.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 teddy bear, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 car, 29.3ms
# Speed: 8.1ms preprocess, 29.3ms inference, 22.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 teddy bear, 27.8ms
# Speed: 4.2ms preprocess, 27.8ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 traffic light, 1 teddy bear, 97.9ms
# Speed: 11.3ms preprocess, 97.9ms inference, 18.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 45.3ms
# Speed: 5.6ms preprocess, 45.3ms inference, 33.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 parking meter, 1 teddy bear, 33.2ms
# Speed: 5.4ms preprocess, 33.2ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 3 teddy bears, 29.5ms
# Speed: 4.8ms preprocess, 29.5ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 teddy bear, 98.2ms
# Speed: 15.8ms preprocess, 98.2ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 teddy bears, 26.1ms
# Speed: 3.8ms preprocess, 26.1ms inference, 22.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 3 fire hydrants, 2 teddy bears, 116.3ms
# Speed: 17.1ms preprocess, 116.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 2 fire hydrants, 5 teddy bears, 32.4ms
# Speed: 8.5ms preprocess, 32.4ms inference, 22.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 fire hydrant, 6 teddy bears, 48.2ms
# Speed: 7.6ms preprocess, 48.2ms inference, 23.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 6 teddy bears, 29.4ms
# Speed: 8.5ms preprocess, 29.4ms inference, 18.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 3 teddy bears, 105.2ms
# Speed: 20.2ms preprocess, 105.2ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 train, 5 teddy bears, 25.1ms
# Speed: 4.4ms preprocess, 25.1ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 5 teddy bears, 49.0ms
# Speed: 15.9ms preprocess, 49.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 sports ball, 2 teddy bears, 24.1ms
# Speed: 4.3ms preprocess, 24.1ms inference, 21.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 traffic light, 1 sports ball, 89.1ms
# Speed: 32.4ms preprocess, 89.1ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 traffic light, 1 fire hydrant, 1 sports ball, 2 teddy bears, 23.7ms
# Speed: 3.6ms preprocess, 23.7ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 traffic light, 1 fire hydrant, 1 sports ball, 2 teddy bears, 25.8ms
# Speed: 5.9ms preprocess, 25.8ms inference, 19.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 traffic light, 1 fire hydrant, 1 sports ball, 4 teddy bears, 130.3ms
# Speed: 16.6ms preprocess, 130.3ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 traffic light, 3 teddy bears, 107.4ms
# Speed: 18.6ms preprocess, 107.4ms inference, 18.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 fire hydrant, 2 teddy bears, 28.9ms
# Speed: 3.5ms preprocess, 28.9ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 fire hydrant, 1 teddy bear, 24.2ms
# Speed: 4.5ms preprocess, 24.2ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 fire hydrant, 6 teddy bears, 84.2ms
# Speed: 17.4ms preprocess, 84.2ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 fire hydrant, 3 teddy bears, 62.3ms
# Speed: 12.5ms preprocess, 62.3ms inference, 19.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 fire hydrant, 12 teddy bears, 58.9ms
# Speed: 4.1ms preprocess, 58.9ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 fire hydrant, 1 handbag, 7 teddy bears, 37.5ms
# Speed: 9.4ms preprocess, 37.5ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 fire hydrant, 11 teddy bears, 116.8ms
# Speed: 21.9ms preprocess, 116.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 fire hydrant, 9 teddy bears, 69.4ms
# Speed: 17.1ms preprocess, 69.4ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 fire hydrant, 4 teddy bears, 76.7ms
# Speed: 17.6ms preprocess, 76.7ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 6 teddy bears, 23.7ms
# Speed: 4.2ms preprocess, 23.7ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 fire hydrant, 8 teddy bears, 23.7ms
# Speed: 5.0ms preprocess, 23.7ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 fire hydrant, 102.0ms
# Speed: 16.8ms preprocess, 102.0ms inference, 19.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 traffic light, 1 fire hydrant, 4 teddy bears, 66.6ms
# Speed: 17.9ms preprocess, 66.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 fire hydrant, 6 teddy bears, 23.9ms
# Speed: 2.9ms preprocess, 23.9ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 fire hydrant, 9 teddy bears, 28.7ms
# Speed: 14.5ms preprocess, 28.7ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 11 teddy bears, 25.7ms
# Speed: 4.8ms preprocess, 25.7ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 13 teddy bears, 36.9ms
# Speed: 7.3ms preprocess, 36.9ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 fire hydrants, 14 teddy bears, 111.2ms
# Speed: 33.6ms preprocess, 111.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 fire hydrant, 10 teddy bears, 32.4ms
# Speed: 5.7ms preprocess, 32.4ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 refrigerator, 12 teddy bears, 37.8ms
# Speed: 18.8ms preprocess, 37.8ms inference, 19.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 fire hydrant, 1 refrigerator, 14 teddy bears, 28.9ms
# Speed: 4.9ms preprocess, 28.9ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 fire hydrant, 1 refrigerator, 12 teddy bears, 88.9ms
# Speed: 32.5ms preprocess, 88.9ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 fire hydrants, 13 teddy bears, 69.8ms
# Speed: 16.6ms preprocess, 69.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 fire hydrants, 7 teddy bears, 25.7ms
# Speed: 4.2ms preprocess, 25.7ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 9 teddy bears, 33.5ms
# Speed: 3.9ms preprocess, 33.5ms inference, 41.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 teddy bears, 105.2ms
# Speed: 15.7ms preprocess, 105.2ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 fire hydrant, 5 teddy bears, 26.8ms
# Speed: 3.6ms preprocess, 26.8ms inference, 22.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 teddy bears, 106.4ms
# Speed: 21.3ms preprocess, 106.4ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 teddy bears, 24.7ms
# Speed: 3.9ms preprocess, 24.7ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 12 teddy bears, 113.6ms
# Speed: 17.7ms preprocess, 113.6ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 fire hydrant, 7 teddy bears, 23.9ms
# Speed: 4.1ms preprocess, 23.9ms inference, 19.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 fire hydrants, 10 teddy bears, 67.8ms
# Speed: 22.8ms preprocess, 67.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 fire hydrant, 12 teddy bears, 26.6ms
# Speed: 4.2ms preprocess, 26.6ms inference, 18.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 fire hydrant, 17 teddy bears, 117.9ms
# Speed: 22.3ms preprocess, 117.9ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 fire hydrants, 11 teddy bears, 24.3ms
# Speed: 3.9ms preprocess, 24.3ms inference, 17.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 18 teddy bears, 107.2ms
# Speed: 20.3ms preprocess, 107.2ms inference, 21.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 fire hydrant, 11 teddy bears, 24.5ms
# Speed: 3.4ms preprocess, 24.5ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 fire hydrant, 15 teddy bears, 121.4ms
# Speed: 19.3ms preprocess, 121.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 traffic light, 2 fire hydrants, 9 teddy bears, 23.7ms
# Speed: 4.2ms preprocess, 23.7ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 traffic light, 12 teddy bears, 46.3ms
# Speed: 18.3ms preprocess, 46.3ms inference, 24.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 fire hydrants, 12 teddy bears, 28.1ms
# Speed: 5.2ms preprocess, 28.1ms inference, 16.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 13 teddy bears, 64.0ms
# Speed: 20.6ms preprocess, 64.0ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 12 teddy bears, 129.8ms
# Speed: 18.1ms preprocess, 129.8ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 fire hydrant, 10 teddy bears, 77.6ms
# Speed: 3.9ms preprocess, 77.6ms inference, 22.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 fire hydrant, 8 teddy bears, 81.4ms
# Speed: 4.9ms preprocess, 81.4ms inference, 21.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 fire hydrant, 13 teddy bears, 66.7ms
# Speed: 19.3ms preprocess, 66.7ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 fire hydrant, 12 teddy bears, 87.1ms
# Speed: 16.5ms preprocess, 87.1ms inference, 20.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 fire hydrant, 11 teddy bears, 29.0ms
# Speed: 5.2ms preprocess, 29.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 fire hydrant, 10 teddy bears, 49.4ms
# Speed: 24.5ms preprocess, 49.4ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 fire hydrant, 5 teddy bears, 26.4ms
# Speed: 3.2ms preprocess, 26.4ms inference, 19.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 teddy bears, 108.4ms
# Speed: 20.2ms preprocess, 108.4ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 fire hydrant, 10 teddy bears, 73.4ms
# Speed: 21.8ms preprocess, 73.4ms inference, 19.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 fire hydrant, 14 teddy bears, 34.0ms
# Speed: 13.3ms preprocess, 34.0ms inference, 23.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 teddy bears, 57.5ms
# Speed: 16.6ms preprocess, 57.5ms inference, 17.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 11 teddy bears, 30.7ms
# Speed: 9.2ms preprocess, 30.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 fire hydrant, 7 teddy bears, 23.9ms
# Speed: 4.6ms preprocess, 23.9ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 8 teddy bears, 25.1ms
# Speed: 4.0ms preprocess, 25.1ms inference, 16.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 fire hydrant, 6 teddy bears, 113.6ms
# Speed: 17.6ms preprocess, 113.6ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 12 teddy bears, 114.4ms
# Speed: 17.1ms preprocess, 114.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 fire hydrant, 6 teddy bears, 90.7ms
# Speed: 21.0ms preprocess, 90.7ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 fire hydrants, 4 teddy bears, 34.0ms
# Speed: 7.0ms preprocess, 34.0ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 6 teddy bears, 64.8ms
# Speed: 11.5ms preprocess, 64.8ms inference, 21.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 fire hydrant, 9 teddy bears, 42.9ms
# Speed: 6.0ms preprocess, 42.9ms inference, 22.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 fire hydrant, 7 teddy bears, 100.0ms
# Speed: 18.3ms preprocess, 100.0ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 fire hydrant, 8 teddy bears, 46.7ms
# Speed: 7.6ms preprocess, 46.7ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 fire hydrants, 6 teddy bears, 25.4ms
# Speed: 3.6ms preprocess, 25.4ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 truck, 2 fire hydrants, 5 teddy bears, 40.0ms
# Speed: 20.7ms preprocess, 40.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 fire hydrant, 8 teddy bears, 23.8ms
# Speed: 3.8ms preprocess, 23.8ms inference, 22.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 fire hydrants, 7 teddy bears, 90.9ms
# Speed: 16.5ms preprocess, 90.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 fire hydrant, 7 teddy bears, 24.0ms
# Speed: 2.6ms preprocess, 24.0ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 train, 2 fire hydrants, 1 teddy bear, 34.3ms
# Speed: 13.4ms preprocess, 34.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 10 teddy bears, 23.9ms
# Speed: 3.5ms preprocess, 23.9ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 7 teddy bears, 27.8ms
# Speed: 6.0ms preprocess, 27.8ms inference, 17.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 fire hydrants, 4 teddy bears, 25.9ms
# Speed: 3.4ms preprocess, 25.9ms inference, 25.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 5 teddy bears, 25.2ms
# Speed: 6.2ms preprocess, 25.2ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 8 teddy bears, 32.6ms
# Speed: 12.6ms preprocess, 32.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 2 fire hydrants, 6 teddy bears, 23.6ms
# Speed: 3.6ms preprocess, 23.6ms inference, 17.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 2 fire hydrants, 7 teddy bears, 94.0ms
# Speed: 4.8ms preprocess, 94.0ms inference, 18.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 3 fire hydrants, 10 teddy bears, 23.9ms
# Speed: 5.1ms preprocess, 23.9ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 fire hydrant, 10 teddy bears, 31.1ms
# Speed: 7.4ms preprocess, 31.1ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 5 teddy bears, 32.2ms
# Speed: 8.5ms preprocess, 32.2ms inference, 21.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 6 teddy bears, 70.1ms
# Speed: 2.7ms preprocess, 70.1ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 fire hydrant, 3 teddy bears, 81.1ms
# Speed: 4.3ms preprocess, 81.1ms inference, 21.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 fire hydrant, 3 teddy bears, 29.0ms
# Speed: 9.3ms preprocess, 29.0ms inference, 23.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 fire hydrant, 1 dog, 1 sports ball, 2 teddy bears, 35.6ms
# Speed: 8.5ms preprocess, 35.6ms inference, 20.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 train, 1 fire hydrant, 3 teddy bears, 29.2ms
# Speed: 5.5ms preprocess, 29.2ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 fire hydrants, 1 sports ball, 3 teddy bears, 29.4ms
# Speed: 4.2ms preprocess, 29.4ms inference, 21.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 2 fire hydrants, 1 sports ball, 101.8ms
# Speed: 18.3ms preprocess, 101.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 fire hydrant, 1 sports ball, 4 teddy bears, 29.9ms
# Speed: 3.8ms preprocess, 29.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 sports ball, 8 teddy bears, 83.8ms
# Speed: 28.8ms preprocess, 83.8ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 fire hydrants, 3 teddy bears, 49.4ms
# Speed: 16.1ms preprocess, 49.4ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 traffic light, 2 fire hydrants, 84.6ms
# Speed: 28.6ms preprocess, 84.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 traffic light, 3 fire hydrants, 1 teddy bear, 24.4ms
# Speed: 4.5ms preprocess, 24.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 fire hydrants, 2 teddy bears, 24.9ms
# Speed: 3.2ms preprocess, 24.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 train, 2 fire hydrants, 1 teddy bear, 24.1ms
# Speed: 3.3ms preprocess, 24.1ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 fire hydrants, 3 teddy bears, 97.7ms
# Speed: 20.3ms preprocess, 97.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 fire hydrant, 3 teddy bears, 24.5ms
# Speed: 2.6ms preprocess, 24.5ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 fire hydrant, 2 teddy bears, 40.1ms
# Speed: 17.2ms preprocess, 40.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 fire hydrant, 2 teddy bears, 24.0ms
# Speed: 3.8ms preprocess, 24.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 fire hydrants, 2 teddy bears, 48.6ms
# Speed: 17.4ms preprocess, 48.6ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 fire hydrant, 4 teddy bears, 27.5ms
# Speed: 3.4ms preprocess, 27.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 fire hydrant, 6 teddy bears, 23.9ms
# Speed: 4.4ms preprocess, 23.9ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14 teddy bears, 27.3ms
# Speed: 5.1ms preprocess, 27.3ms inference, 18.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 16 teddy bears, 23.6ms
# Speed: 4.6ms preprocess, 23.6ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 11 teddy bears, 29.0ms
# Speed: 8.8ms preprocess, 29.0ms inference, 20.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 fire hydrant, 3 teddy bears, 86.0ms
# Speed: 17.6ms preprocess, 86.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 teddy bear, 23.4ms
# Speed: 3.3ms preprocess, 23.4ms inference, 21.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 fire hydrant, 3 teddy bears, 29.4ms
# Speed: 5.0ms preprocess, 29.4ms inference, 20.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 fire hydrants, 1 teddy bear, 24.4ms
# Speed: 4.6ms preprocess, 24.4ms inference, 21.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 3 teddy bears, 30.8ms
# Speed: 9.6ms preprocess, 30.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 teddy bear, 23.8ms
# Speed: 2.6ms preprocess, 23.8ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 teddy bear, 35.1ms
# Speed: 14.2ms preprocess, 35.1ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 fire hydrants, 1 teddy bear, 23.7ms
# Speed: 3.3ms preprocess, 23.7ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 fire hydrant, 1 teddy bear, 37.3ms
# Speed: 20.2ms preprocess, 37.3ms inference, 18.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 teddy bear, 66.5ms
# Speed: 4.4ms preprocess, 66.5ms inference, 22.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 3 teddy bears, 90.9ms
# Speed: 2.7ms preprocess, 90.9ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 fire hydrant, 5 teddy bears, 25.6ms
# Speed: 7.4ms preprocess, 25.6ms inference, 20.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 teddy bears, 29.1ms
# Speed: 6.7ms preprocess, 29.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 6 teddy bears, 24.0ms
# Speed: 2.6ms preprocess, 24.0ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 fire hydrant, 1 chair, 2 teddy bears, 30.7ms
# Speed: 10.1ms preprocess, 30.7ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 chair, 4 teddy bears, 62.2ms
# Speed: 17.0ms preprocess, 62.2ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 5 teddy bears, 29.6ms
# Speed: 7.7ms preprocess, 29.6ms inference, 30.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 5 teddy bears, 82.5ms
# Speed: 8.3ms preprocess, 82.5ms inference, 18.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 4 teddy bears, 33.9ms
# Speed: 3.8ms preprocess, 33.9ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 7 teddy bears, 74.7ms
# Speed: 19.7ms preprocess, 74.7ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 2 teddy bears, 121.1ms
# Speed: 18.4ms preprocess, 121.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 fire hydrant, 4 teddy bears, 28.3ms
# Speed: 7.3ms preprocess, 28.3ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 teddy bear, 24.6ms
# Speed: 3.8ms preprocess, 24.6ms inference, 20.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 2 fire hydrants, 1 teddy bear, 24.6ms
# Speed: 4.5ms preprocess, 24.6ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 teddy bear, 87.1ms
# Speed: 7.6ms preprocess, 87.1ms inference, 19.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 3 teddy bears, 24.1ms
# Speed: 4.3ms preprocess, 24.1ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 4 teddy bears, 69.0ms
# Speed: 18.2ms preprocess, 69.0ms inference, 17.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 3 teddy bears, 43.3ms
# Speed: 10.6ms preprocess, 43.3ms inference, 19.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 3 teddy bears, 83.2ms
# Speed: 18.7ms preprocess, 83.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 fire hydrants, 3 teddy bears, 24.4ms
# Speed: 3.4ms preprocess, 24.4ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 3 teddy bears, 66.7ms
# Speed: 7.2ms preprocess, 66.7ms inference, 21.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 teddy bears, 26.2ms
# Speed: 6.6ms preprocess, 26.2ms inference, 16.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 teddy bears, 119.8ms
# Speed: 18.4ms preprocess, 119.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 teddy bear, 26.8ms
# Speed: 6.1ms preprocess, 26.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 5 teddy bears, 24.1ms
# Speed: 3.9ms preprocess, 24.1ms inference, 21.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 2 fire hydrants, 1 teddy bear, 33.0ms
# Speed: 6.1ms preprocess, 33.0ms inference, 21.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 4 teddy bears, 81.4ms
# Speed: 28.6ms preprocess, 81.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 6 teddy bears, 23.7ms
# Speed: 3.3ms preprocess, 23.7ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 train, 1 sports ball, 1 teddy bear, 77.7ms
# Speed: 7.3ms preprocess, 77.7ms inference, 18.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 3 teddy bears, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 3 teddy bears, 24.8ms
# Speed: 3.0ms preprocess, 24.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 3 teddy bears, 28.8ms
# Speed: 3.9ms preprocess, 28.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 teddy bear, 24.5ms
# Speed: 3.2ms preprocess, 24.5ms inference, 21.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 2 teddy bears, 25.8ms
# Speed: 2.9ms preprocess, 25.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bench, 4 teddy bears, 24.8ms
# Speed: 3.4ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 teddy bears, 24.8ms
# Speed: 3.1ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 2 teddy bears, 24.3ms
# Speed: 3.2ms preprocess, 24.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 teddy bear, 24.8ms
# Speed: 3.5ms preprocess, 24.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 trains, 2 teddy bears, 23.7ms
# Speed: 3.6ms preprocess, 23.7ms inference, 22.5ms postprocess per image at shape (1, 3, 384, 640)
# Most people in frame: 41001 with 29 persons
# Largest person in frame: 41014 with size 58520
# Smallest person in frame: 41197 with size 2814
