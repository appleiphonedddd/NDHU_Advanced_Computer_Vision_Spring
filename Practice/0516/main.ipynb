# %% [markdown]
# ## Practice : People detector and analyzer
#
# 1. Input images from wiiplay.mp4 with frame number between 41000 and 44000.
# 2. Use YOLOv8 to detect people, mark as red rectangle, and count how many persons in each frame. (hint: check label == 'person')
# 3. Try to find out which frame contains the most number of persons. (print the number of persons on the upper-left corner)
# 4. (optional) Try to find out which frame containes the largest person. (print the size of its bounding box on the upper-left corner)
# 5. (optional) Try to find out which frame containes the smallest person. (print the size of its bounding box on the upper-left corner)
# 6. Show the three output frames you found.
# 7. Verify the correctness of your output, then adjust the desired confidence threshold for improvement.
# 8. Upload your Jupyter code file (*.ipynb)

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
# load the video
cap = cv2.VideoCapture('WiiPlay.mp4')

# Initialize variables to store the frame number with the most people, the number of people in that frame

most_people_frame = None
most_people_count = 0

largest_person_frame = None
largest_person_size = 0

smallest_person_frame = None
smallest_person_size = float('inf')

# Set the start and end frame
start_frame = 41000
end_frame = 44000

current_frame_number = start_frame

cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

while True:
    # Read the frame
    ret, img = cap.read()
    if not ret or current_frame_number > end_frame:
        break

    current_frame_number += 1
    
    # Flip the image horizontally
    img = cv2.flip(img, 1)

    # Load the image to the YOLOv8 model, according to the testing, the range of the image should be 0.1 to 0.2 for the best result
    results = model.predict(img, conf=0.1000112)

    # Init variables to store the number of persons, the largest and smallest person size
    person_count = 0
    frame_largest_size = 0
    frame_smallest_size = float('inf')

    # Init list to store the bounding boxes
    bounding_boxes = []

    # Loop through the results and draw the bounding boxes on the image.
    
    for result in results:
        for box in result.boxes:
            label = results[0].names[int(box.cls)]

            # If the label is person, draw the bounding box
            if label == 'person':
                person_count += 1

                # Get the bounding box coordinates
                left, top, right, bottom = np.array(box.xyxy.cpu(), dtype=np.uint16).squeeze()

                """
                Calculate the width, height, and size of the bounding box.
                Append the bounding box coordinates and size to the bounding_boxes list.
                Update the frame_largest_size and frame_smallest_size if needed.
                """
                width = right - left
                height = bottom - top
                size = width * height
                bounding_boxes.append((left, top, width, height, size))

                # Update the frame_largest_size and frame_smallest_size

                if size > frame_largest_size:
                    frame_largest_size = size
                if size < frame_smallest_size:
                    frame_smallest_size = size

                # Draw the bounding box and label
                cv2.rectangle(img, (left, top), (right, bottom), (0, 255, 0), 2)

                # Add the confidence to the label
                confidence = float(box.conf.cpu())

                # Add the label to the bounding box
                cv2.putText(img, label, (left, top - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36, 255, 12), 2)
            
    # Update most people count frame
    if person_count > most_people_count:
        most_people_count = person_count
        most_people_frame = current_frame_number

    # Update largest person frame
    if frame_largest_size > largest_person_size:
        largest_person_size = frame_largest_size
        largest_person_frame = current_frame_number

    # Update smallest person frame
    if frame_smallest_size < smallest_person_size:
        smallest_person_size = frame_smallest_size
        smallest_person_frame = current_frame_number

    # Print the number of persons on the upper-left corner
    cv2.putText(img, f'Persons: {person_count}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Print the size of each bounding box on the upper-left corner
    for i, (left, top, width, height, size) in enumerate(bounding_boxes):
        cv2.putText(img, f'Size {i+1}: {size}', (10, 60 + i * 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    text = f'Current_Frame: {current_frame_number}'

    # get the size of the text
    text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 1, 2)[0]

    # 10 pixels from the right edge
    text_x = img.shape[1] - text_size[0] - 10

    # 30 pixels from the top edge
    text_y = 30

    # Print the frame number on the upper-right corner 
    cv2.putText(img, text, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Show the image
    cv2.imshow('Result', img)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close the windows
cap.release()
cv2.destroyAllWindows()

"""
Print the frame number with the most people, the number of people in that frame,
the frame number with the largest person, the size of the largest person,
the frame number with the smallest person, and the size of the smallest person.
"""

print(f'Most people in frame: {most_people_frame} with {most_people_count} persons')
print(f'Largest person in frame: {largest_person_frame} with size {largest_person_size}')
print(f'Smallest person in frame: {smallest_person_frame} with size {smallest_person_size}')
# Out:
# 0: 384x640 34 persons, 27.7ms
# Speed: 13.8ms preprocess, 27.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 fire hydrant, 27.1ms
# Speed: 3.3ms preprocess, 27.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 29.0ms
# Speed: 4.6ms preprocess, 29.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 24.9ms
# Speed: 4.1ms preprocess, 24.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 2 teddy bears, 24.4ms
# Speed: 3.1ms preprocess, 24.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 4 teddy bears, 23.6ms
# Speed: 2.7ms preprocess, 23.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 teddy bears, 46.4ms
# Speed: 26.1ms preprocess, 46.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 3 teddy bears, 23.4ms
# Speed: 5.0ms preprocess, 23.4ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 sports ball, 1 teddy bear, 28.9ms
# Speed: 6.8ms preprocess, 28.9ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 sports ball, 5 teddy bears, 32.3ms
# Speed: 8.4ms preprocess, 32.3ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 train, 1 teddy bear, 96.8ms
# Speed: 17.6ms preprocess, 96.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 24.1ms
# Speed: 4.6ms preprocess, 24.1ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 teddy bear, 30.8ms
# Speed: 6.4ms preprocess, 30.8ms inference, 19.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 28.5ms
# Speed: 4.3ms preprocess, 28.5ms inference, 22.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 traffic light, 4 teddy bears, 27.4ms
# Speed: 5.3ms preprocess, 27.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 traffic light, 1 teddy bear, 23.8ms
# Speed: 2.7ms preprocess, 23.8ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 teddy bears, 31.7ms
# Speed: 8.3ms preprocess, 31.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 23.7ms
# Speed: 3.6ms preprocess, 23.7ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 parking meter, 1 teddy bear, 103.2ms
# Speed: 11.4ms preprocess, 103.2ms inference, 20.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 4 teddy bears, 24.4ms
# Speed: 5.1ms preprocess, 24.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 teddy bears, 24.7ms
# Speed: 3.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 fire hydrant, 2 teddy bears, 24.4ms
# Speed: 2.8ms preprocess, 24.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 fire hydrants, 8 teddy bears, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 3 teddy bears, 24.9ms
# Speed: 3.1ms preprocess, 24.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 traffic light, 1 teddy bear, 24.7ms
# Speed: 3.2ms preprocess, 24.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 teddy bear, 23.7ms
# Speed: 2.5ms preprocess, 23.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 26.4ms
# Speed: 7.3ms preprocess, 26.4ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 teddy bear, 96.4ms
# Speed: 16.9ms preprocess, 96.4ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 car, 1 parking meter, 40.9ms
# Speed: 26.1ms preprocess, 40.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 teddy bear, 24.9ms
# Speed: 3.2ms preprocess, 24.9ms inference, 19.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 2 traffic lights, 3 teddy bears, 23.9ms
# Speed: 3.2ms preprocess, 23.9ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 fire hydrant, 23.8ms
# Speed: 3.4ms preprocess, 23.8ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 parking meter, 1 teddy bear, 23.6ms
# Speed: 3.2ms preprocess, 23.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 3 teddy bears, 23.6ms
# Speed: 3.2ms preprocess, 23.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 teddy bear, 23.9ms
# Speed: 4.1ms preprocess, 23.9ms inference, 19.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 teddy bears, 24.0ms
# Speed: 3.1ms preprocess, 24.0ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 3 fire hydrants, 1 parking meter, 2 teddy bears, 23.7ms
# Speed: 4.4ms preprocess, 23.7ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 car, 2 fire hydrants, 5 teddy bears, 23.9ms
# Speed: 2.8ms preprocess, 23.9ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 fire hydrant, 6 teddy bears, 29.4ms
# Speed: 6.3ms preprocess, 29.4ms inference, 20.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 6 teddy bears, 118.2ms
# Speed: 16.6ms preprocess, 118.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 4 teddy bears, 25.0ms
# Speed: 2.6ms preprocess, 25.0ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 train, 5 teddy bears, 73.6ms
# Speed: 18.9ms preprocess, 73.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 5 teddy bears, 23.7ms
# Speed: 3.8ms preprocess, 23.7ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 3 teddy bears, 46.0ms
# Speed: 12.7ms preprocess, 46.0ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 traffic light, 1 sports ball, 69.6ms
# Speed: 19.7ms preprocess, 69.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 traffic light, 1 fire hydrant, 1 sports ball, 2 teddy bears, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 traffic light, 1 fire hydrant, 1 sports ball, 2 teddy bears, 23.6ms
# Speed: 4.1ms preprocess, 23.6ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 traffic light, 1 fire hydrant, 1 sports ball, 4 teddy bears, 30.1ms
# Speed: 7.8ms preprocess, 30.1ms inference, 22.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 traffic light, 1 fire hydrant, 1 sports ball, 3 teddy bears, 96.4ms
# Speed: 19.6ms preprocess, 96.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 fire hydrant, 2 teddy bears, 75.8ms
# Speed: 16.5ms preprocess, 75.8ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 fire hydrant, 1 teddy bear, 33.1ms
# Speed: 7.0ms preprocess, 33.1ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 fire hydrant, 6 teddy bears, 27.4ms
# Speed: 5.2ms preprocess, 27.4ms inference, 27.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 fire hydrant, 4 teddy bears, 26.9ms
# Speed: 4.7ms preprocess, 26.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 fire hydrant, 14 teddy bears, 23.9ms
# Speed: 5.6ms preprocess, 23.9ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 fire hydrant, 1 handbag, 7 teddy bears, 112.2ms
# Speed: 20.4ms preprocess, 112.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 fire hydrant, 14 teddy bears, 48.4ms
# Speed: 21.6ms preprocess, 48.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 fire hydrant, 10 teddy bears, 125.0ms
# Speed: 19.8ms preprocess, 125.0ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 fire hydrant, 4 teddy bears, 24.1ms
# Speed: 2.8ms preprocess, 24.1ms inference, 19.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 7 teddy bears, 23.7ms
# Speed: 5.3ms preprocess, 23.7ms inference, 20.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 fire hydrant, 8 teddy bears, 23.6ms
# Speed: 2.9ms preprocess, 23.6ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 fire hydrant, 3 teddy bears, 26.5ms
# Speed: 4.0ms preprocess, 26.5ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 traffic light, 1 fire hydrant, 5 teddy bears, 25.4ms
# Speed: 4.3ms preprocess, 25.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 fire hydrant, 8 teddy bears, 24.3ms
# Speed: 2.7ms preprocess, 24.3ms inference, 14.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 fire hydrant, 9 teddy bears, 46.1ms
# Speed: 15.6ms preprocess, 46.1ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 12 teddy bears, 24.0ms
# Speed: 3.4ms preprocess, 24.0ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 13 teddy bears, 24.6ms
# Speed: 4.5ms preprocess, 24.6ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 fire hydrants, 14 teddy bears, 29.3ms
# Speed: 8.5ms preprocess, 29.3ms inference, 17.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 fire hydrant, 11 teddy bears, 50.8ms
# Speed: 19.1ms preprocess, 50.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 refrigerator, 12 teddy bears, 23.8ms
# Speed: 2.8ms preprocess, 23.8ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 fire hydrant, 1 refrigerator, 14 teddy bears, 41.4ms
# Speed: 15.6ms preprocess, 41.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 fire hydrant, 1 refrigerator, 12 teddy bears, 24.1ms
# Speed: 2.9ms preprocess, 24.1ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 fire hydrants, 14 teddy bears, 26.2ms
# Speed: 4.6ms preprocess, 26.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 fire hydrants, 7 teddy bears, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 9 teddy bears, 30.9ms
# Speed: 12.3ms preprocess, 30.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 teddy bears, 23.9ms
# Speed: 2.7ms preprocess, 23.9ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 fire hydrants, 6 teddy bears, 30.8ms
# Speed: 11.6ms preprocess, 30.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 teddy bears, 23.9ms
# Speed: 3.9ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 9 teddy bears, 23.7ms
# Speed: 3.6ms preprocess, 23.7ms inference, 15.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 14 teddy bears, 26.1ms
# Speed: 3.9ms preprocess, 26.1ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 fire hydrant, 12 teddy bears, 97.5ms
# Speed: 19.9ms preprocess, 97.5ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 fire hydrants, 11 teddy bears, 89.9ms
# Speed: 11.2ms preprocess, 89.9ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 fire hydrant, 16 teddy bears, 75.9ms
# Speed: 21.5ms preprocess, 75.9ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 fire hydrant, 18 teddy bears, 117.6ms
# Speed: 17.7ms preprocess, 117.6ms inference, 21.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 fire hydrants, 12 teddy bears, 90.3ms
# Speed: 3.6ms preprocess, 90.3ms inference, 15.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 19 teddy bears, 85.9ms
# Speed: 19.0ms preprocess, 85.9ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 fire hydrant, 13 teddy bears, 42.4ms
# Speed: 3.9ms preprocess, 42.4ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 traffic light, 1 fire hydrant, 17 teddy bears, 24.0ms
# Speed: 3.9ms preprocess, 24.0ms inference, 19.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 traffic light, 2 fire hydrants, 9 teddy bears, 117.8ms
# Speed: 17.4ms preprocess, 117.8ms inference, 18.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 traffic light, 13 teddy bears, 23.4ms
# Speed: 3.4ms preprocess, 23.4ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 fire hydrants, 13 teddy bears, 114.9ms
# Speed: 16.2ms preprocess, 114.9ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 14 teddy bears, 24.7ms
# Speed: 4.1ms preprocess, 24.7ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 12 teddy bears, 113.6ms
# Speed: 16.1ms preprocess, 113.6ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 fire hydrant, 12 teddy bears, 95.2ms
# Speed: 5.6ms preprocess, 95.2ms inference, 20.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 fire hydrant, 8 teddy bears, 88.7ms
# Speed: 3.9ms preprocess, 88.7ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 fire hydrant, 16 teddy bears, 57.4ms
# Speed: 18.2ms preprocess, 57.4ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 fire hydrant, 14 teddy bears, 58.0ms
# Speed: 26.9ms preprocess, 58.0ms inference, 30.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 fire hydrants, 13 teddy bears, 113.7ms
# Speed: 30.5ms preprocess, 113.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 fire hydrant, 10 teddy bears, 105.7ms
# Speed: 3.7ms preprocess, 105.7ms inference, 26.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 fire hydrant, 7 teddy bears, 72.3ms
# Speed: 15.1ms preprocess, 72.3ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 teddy bears, 36.3ms
# Speed: 7.1ms preprocess, 36.3ms inference, 22.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 fire hydrant, 12 teddy bears, 114.8ms
# Speed: 22.0ms preprocess, 114.8ms inference, 20.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 fire hydrant, 15 teddy bears, 112.9ms
# Speed: 4.2ms preprocess, 112.9ms inference, 21.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 12 teddy bears, 71.1ms
# Speed: 18.0ms preprocess, 71.1ms inference, 32.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 fire hydrant, 11 teddy bears, 34.8ms
# Speed: 18.1ms preprocess, 34.8ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 fire hydrant, 9 teddy bears, 106.8ms
# Speed: 17.6ms preprocess, 106.8ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 9 teddy bears, 92.7ms
# Speed: 4.3ms preprocess, 92.7ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 fire hydrant, 7 teddy bears, 54.2ms
# Speed: 25.5ms preprocess, 54.2ms inference, 32.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 12 teddy bears, 90.2ms
# Speed: 19.8ms preprocess, 90.2ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 fire hydrant, 8 teddy bears, 98.2ms
# Speed: 15.8ms preprocess, 98.2ms inference, 23.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 fire hydrants, 6 teddy bears, 51.5ms
# Speed: 5.2ms preprocess, 51.5ms inference, 18.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 6 teddy bears, 38.0ms
# Speed: 11.1ms preprocess, 38.0ms inference, 21.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 fire hydrant, 9 teddy bears, 101.2ms
# Speed: 25.0ms preprocess, 101.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 fire hydrant, 8 teddy bears, 29.5ms
# Speed: 4.2ms preprocess, 29.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 fire hydrant, 8 teddy bears, 28.2ms
# Speed: 3.7ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 fire hydrants, 6 teddy bears, 24.6ms
# Speed: 2.9ms preprocess, 24.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 truck, 2 fire hydrants, 6 teddy bears, 24.7ms
# Speed: 3.3ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 fire hydrant, 9 teddy bears, 24.3ms
# Speed: 3.3ms preprocess, 24.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 fire hydrants, 8 teddy bears, 41.1ms
# Speed: 2.9ms preprocess, 41.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 fire hydrant, 8 teddy bears, 27.5ms
# Speed: 4.3ms preprocess, 27.5ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 train, 2 fire hydrants, 1 teddy bear, 27.3ms
# Speed: 5.8ms preprocess, 27.3ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 10 teddy bears, 25.6ms
# Speed: 7.9ms preprocess, 25.6ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 8 teddy bears, 31.1ms
# Speed: 14.2ms preprocess, 31.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 fire hydrants, 4 teddy bears, 23.7ms
# Speed: 3.1ms preprocess, 23.7ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 6 teddy bears, 24.6ms
# Speed: 4.5ms preprocess, 24.6ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 9 teddy bears, 26.5ms
# Speed: 6.3ms preprocess, 26.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 2 fire hydrants, 8 teddy bears, 23.8ms
# Speed: 2.9ms preprocess, 23.8ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 2 fire hydrants, 7 teddy bears, 92.7ms
# Speed: 19.8ms preprocess, 92.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 3 fire hydrants, 12 teddy bears, 23.6ms
# Speed: 2.8ms preprocess, 23.6ms inference, 17.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 fire hydrant, 12 teddy bears, 41.9ms
# Speed: 18.2ms preprocess, 41.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 5 teddy bears, 23.6ms
# Speed: 2.9ms preprocess, 23.6ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 train, 6 teddy bears, 30.6ms
# Speed: 7.5ms preprocess, 30.6ms inference, 15.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 fire hydrant, 4 teddy bears, 33.7ms
# Speed: 14.2ms preprocess, 33.7ms inference, 15.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 fire hydrant, 3 teddy bears, 31.8ms
# Speed: 8.7ms preprocess, 31.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 fire hydrant, 1 dog, 1 sports ball, 2 teddy bears, 23.9ms
# Speed: 2.8ms preprocess, 23.9ms inference, 17.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 train, 1 fire hydrant, 3 teddy bears, 73.7ms
# Speed: 15.5ms preprocess, 73.7ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 fire hydrants, 1 sports ball, 3 teddy bears, 23.8ms
# Speed: 4.7ms preprocess, 23.8ms inference, 19.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 3 fire hydrants, 1 sports ball, 103.9ms
# Speed: 19.6ms preprocess, 103.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 fire hydrant, 1 sports ball, 4 teddy bears, 24.4ms
# Speed: 2.8ms preprocess, 24.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 8 teddy bears, 24.5ms
# Speed: 3.1ms preprocess, 24.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 fire hydrants, 5 teddy bears, 24.5ms
# Speed: 3.2ms preprocess, 24.5ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 traffic light, 2 fire hydrants, 1 teddy bear, 37.4ms
# Speed: 17.4ms preprocess, 37.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 traffic light, 3 fire hydrants, 1 teddy bear, 24.4ms
# Speed: 3.0ms preprocess, 24.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 2 fire hydrants, 2 teddy bears, 24.5ms
# Speed: 3.0ms preprocess, 24.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 train, 3 fire hydrants, 1 teddy bear, 24.3ms
# Speed: 2.8ms preprocess, 24.3ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 fire hydrants, 4 teddy bears, 24.2ms
# Speed: 4.3ms preprocess, 24.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 fire hydrants, 3 teddy bears, 24.5ms
# Speed: 2.7ms preprocess, 24.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 fire hydrant, 2 teddy bears, 24.0ms
# Speed: 3.2ms preprocess, 24.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 fire hydrant, 2 teddy bears, 24.0ms
# Speed: 2.8ms preprocess, 24.0ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 fire hydrants, 4 teddy bears, 35.5ms
# Speed: 17.0ms preprocess, 35.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 fire hydrant, 4 teddy bears, 24.1ms
# Speed: 3.6ms preprocess, 24.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 fire hydrant, 8 teddy bears, 24.2ms
# Speed: 2.9ms preprocess, 24.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 16 teddy bears, 24.4ms
# Speed: 2.7ms preprocess, 24.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 19 teddy bears, 27.2ms
# Speed: 5.5ms preprocess, 27.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 13 teddy bears, 24.3ms
# Speed: 3.5ms preprocess, 24.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 fire hydrant, 4 teddy bears, 24.5ms
# Speed: 2.9ms preprocess, 24.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 train, 1 fire hydrant, 2 teddy bears, 24.8ms
# Speed: 3.5ms preprocess, 24.8ms inference, 20.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 train, 1 fire hydrant, 3 teddy bears, 42.7ms
# Speed: 6.1ms preprocess, 42.7ms inference, 28.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 2 fire hydrants, 2 teddy bears, 24.1ms
# Speed: 4.0ms preprocess, 24.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 4 teddy bears, 24.1ms
# Speed: 2.9ms preprocess, 24.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 teddy bear, 24.4ms
# Speed: 2.9ms preprocess, 24.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 2 teddy bears, 23.5ms
# Speed: 2.7ms preprocess, 23.5ms inference, 18.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 2 fire hydrants, 1 teddy bear, 57.4ms
# Speed: 14.9ms preprocess, 57.4ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 fire hydrant, 1 teddy bear, 93.5ms
# Speed: 20.4ms preprocess, 93.5ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 teddy bear, 94.4ms
# Speed: 22.0ms preprocess, 94.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 sports ball, 3 teddy bears, 24.0ms
# Speed: 4.1ms preprocess, 24.0ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 fire hydrant, 6 teddy bears, 70.1ms
# Speed: 24.1ms preprocess, 70.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 4 teddy bears, 50.2ms
# Speed: 19.2ms preprocess, 50.2ms inference, 19.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 8 teddy bears, 84.3ms
# Speed: 21.9ms preprocess, 84.3ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 2 fire hydrants, 1 chair, 2 teddy bears, 24.7ms
# Speed: 4.5ms preprocess, 24.7ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 chair, 5 teddy bears, 59.9ms
# Speed: 21.4ms preprocess, 59.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 chair, 5 teddy bears, 26.0ms
# Speed: 2.8ms preprocess, 26.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 7 teddy bears, 24.2ms
# Speed: 3.1ms preprocess, 24.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 5 teddy bears, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 9 teddy bears, 23.6ms
# Speed: 2.7ms preprocess, 23.6ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 5 teddy bears, 103.8ms
# Speed: 18.1ms preprocess, 103.8ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 fire hydrant, 4 teddy bears, 26.6ms
# Speed: 3.7ms preprocess, 26.6ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 teddy bears, 115.4ms
# Speed: 16.1ms preprocess, 115.4ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 2 fire hydrants, 1 teddy bear, 42.7ms
# Speed: 4.8ms preprocess, 42.7ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 teddy bear, 28.5ms
# Speed: 3.5ms preprocess, 28.5ms inference, 17.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 fire hydrant, 3 teddy bears, 60.7ms
# Speed: 21.9ms preprocess, 60.7ms inference, 21.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 4 teddy bears, 67.0ms
# Speed: 19.3ms preprocess, 67.0ms inference, 19.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 dog, 3 teddy bears, 61.9ms
# Speed: 18.0ms preprocess, 61.9ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 4 teddy bears, 100.4ms
# Speed: 19.4ms preprocess, 100.4ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 2 fire hydrants, 3 teddy bears, 105.6ms
# Speed: 18.8ms preprocess, 105.6ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 3 teddy bears, 111.4ms
# Speed: 19.3ms preprocess, 111.4ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 teddy bears, 23.4ms
# Speed: 3.1ms preprocess, 23.4ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 teddy bears, 113.6ms
# Speed: 17.3ms preprocess, 113.6ms inference, 19.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 teddy bear, 23.6ms
# Speed: 3.6ms preprocess, 23.6ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 5 teddy bears, 114.3ms
# Speed: 16.1ms preprocess, 114.3ms inference, 22.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 2 fire hydrants, 1 teddy bear, 97.9ms
# Speed: 3.3ms preprocess, 97.9ms inference, 19.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 6 teddy bears, 25.3ms
# Speed: 5.4ms preprocess, 25.3ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 6 teddy bears, 85.9ms
# Speed: 22.3ms preprocess, 85.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 train, 1 sports ball, 1 teddy bear, 98.9ms
# Speed: 23.4ms preprocess, 98.9ms inference, 17.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 sports ball, 3 teddy bears, 23.6ms
# Speed: 3.4ms preprocess, 23.6ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 3 teddy bears, 104.6ms
# Speed: 18.4ms preprocess, 104.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 3 teddy bears, 37.4ms
# Speed: 17.6ms preprocess, 37.4ms inference, 18.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 fire hydrant, 1 teddy bear, 92.8ms
# Speed: 16.5ms preprocess, 92.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 3 teddy bears, 23.6ms
# Speed: 3.6ms preprocess, 23.6ms inference, 20.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bench, 4 teddy bears, 98.6ms
# Speed: 18.4ms preprocess, 98.6ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 teddy bears, 25.3ms
# Speed: 4.1ms preprocess, 25.3ms inference, 17.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 3 teddy bears, 106.7ms
# Speed: 16.8ms preprocess, 106.7ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 teddy bear, 84.0ms
# Speed: 18.4ms preprocess, 84.0ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 2 trains, 2 teddy bears, 94.5ms
# Speed: 17.7ms preprocess, 94.5ms inference, 17.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 2 teddy bears, 71.8ms
# Speed: 15.7ms preprocess, 71.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 2 fire hydrants, 80.2ms
# Speed: 2.8ms preprocess, 80.2ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 teddy bears, 45.3ms
# Speed: 5.6ms preprocess, 45.3ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 teddy bear, 71.9ms
# Speed: 4.3ms preprocess, 71.9ms inference, 21.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 fire hydrant, 1 handbag, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 78.9ms
# Speed: 19.5ms preprocess, 78.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 23.3ms
# Speed: 3.4ms preprocess, 23.3ms inference, 15.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 teddy bear, 108.3ms
# Speed: 17.7ms preprocess, 108.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 fire hydrant, 123.6ms
# Speed: 4.1ms preprocess, 123.6ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 99.1ms
# Speed: 3.6ms preprocess, 99.1ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 2 fire hydrants, 1 teddy bear, 23.2ms
# Speed: 3.1ms preprocess, 23.2ms inference, 16.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 4 fire hydrants, 110.4ms
# Speed: 22.9ms preprocess, 110.4ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 car, 2 fire hydrants, 35.6ms
# Speed: 16.5ms preprocess, 35.6ms inference, 19.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 car, 2 fire hydrants, 31.5ms
# Speed: 11.3ms preprocess, 31.5ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 fire hydrants, 26.8ms
# Speed: 6.0ms preprocess, 26.8ms inference, 15.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 fire hydrant, 32.1ms
# Speed: 13.5ms preprocess, 32.1ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 traffic lights, 1 fire hydrant, 2 teddy bears, 23.2ms
# Speed: 4.5ms preprocess, 23.2ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 traffic lights, 2 fire hydrants, 95.9ms
# Speed: 17.3ms preprocess, 95.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 fire hydrant, 23.8ms
# Speed: 2.9ms preprocess, 23.8ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 traffic light, 1 fire hydrant, 1 parking meter, 4 teddy bears, 110.7ms
# Speed: 16.5ms preprocess, 110.7ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 teddy bears, 24.2ms
# Speed: 4.3ms preprocess, 24.2ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 fire hydrant, 3 teddy bears, 117.2ms
# Speed: 16.2ms preprocess, 117.2ms inference, 20.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 54.0ms
# Speed: 2.9ms preprocess, 54.0ms inference, 17.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 25.7ms
# Speed: 4.4ms preprocess, 25.7ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 2 teddy bears, 31.0ms
# Speed: 9.8ms preprocess, 31.0ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 teddy bear, 27.4ms
# Speed: 7.1ms preprocess, 27.4ms inference, 28.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 fire hydrant, 3 teddy bears, 76.5ms
# Speed: 16.3ms preprocess, 76.5ms inference, 17.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 113.7ms
# Speed: 17.9ms preprocess, 113.7ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 fire hydrant, 2 teddy bears, 45.4ms
# Speed: 35.0ms preprocess, 45.4ms inference, 20.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 2 traffic lights, 1 fire hydrant, 93.8ms
# Speed: 34.9ms preprocess, 93.8ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 traffic light, 1 fire hydrant, 1 teddy bear, 102.5ms
# Speed: 4.3ms preprocess, 102.5ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 traffic light, 58.6ms
# Speed: 18.0ms preprocess, 58.6ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 teddy bear, 110.0ms
# Speed: 17.3ms preprocess, 110.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 fire hydrant, 116.4ms
# Speed: 4.9ms preprocess, 116.4ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 fire hydrant, 25.8ms
# Speed: 3.1ms preprocess, 25.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 fire hydrant, 2 teddy bears, 111.8ms
# Speed: 19.1ms preprocess, 111.8ms inference, 19.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 teddy bears, 52.1ms
# Speed: 4.0ms preprocess, 52.1ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 traffic light, 14 teddy bears, 37.4ms
# Speed: 18.5ms preprocess, 37.4ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 traffic lights, 6 teddy bears, 102.3ms
# Speed: 20.1ms preprocess, 102.3ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 traffic light, 2 teddy bears, 27.5ms
# Speed: 5.9ms preprocess, 27.5ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 traffic lights, 2 fire hydrants, 56.2ms
# Speed: 15.7ms preprocess, 56.2ms inference, 19.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 traffic light, 1 teddy bear, 29.3ms
# Speed: 6.2ms preprocess, 29.3ms inference, 21.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 2 traffic lights, 1 teddy bear, 27.0ms
# Speed: 4.7ms preprocess, 27.0ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 traffic lights, 2 fire hydrants, 100.1ms
# Speed: 23.6ms preprocess, 100.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 2 traffic lights, 119.4ms
# Speed: 18.1ms preprocess, 119.4ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 traffic light, 1 teddy bear, 25.8ms
# Speed: 5.9ms preprocess, 25.8ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 parking meter, 1 teddy bear, 58.1ms
# Speed: 20.1ms preprocess, 58.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 24.6ms
# Speed: 3.0ms preprocess, 24.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 24.5ms
# Speed: 2.8ms preprocess, 24.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 24.5ms
# Speed: 3.0ms preprocess, 24.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 teddy bears, 66.1ms
# Speed: 2.8ms preprocess, 66.1ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 3 teddy bears, 25.8ms
# Speed: 5.1ms preprocess, 25.8ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 teddy bears, 46.9ms
# Speed: 18.8ms preprocess, 46.9ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 fire hydrant, 7 teddy bears, 134.3ms
# Speed: 15.8ms preprocess, 134.3ms inference, 21.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 traffic light, 2 teddy bears, 106.8ms
# Speed: 2.6ms preprocess, 106.8ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 teddy bears, 26.3ms
# Speed: 7.8ms preprocess, 26.3ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 teddy bear, 62.7ms
# Speed: 17.5ms preprocess, 62.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 teddy bear, 24.0ms
# Speed: 5.0ms preprocess, 24.0ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 fire hydrant, 2 teddy bears, 71.1ms
# Speed: 17.2ms preprocess, 71.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 fire hydrant, 2 teddy bears, 24.1ms
# Speed: 4.0ms preprocess, 24.1ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 fire hydrant, 2 teddy bears, 135.0ms
# Speed: 15.9ms preprocess, 135.0ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 67.4ms
# Speed: 4.0ms preprocess, 67.4ms inference, 23.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 3 teddy bears, 84.8ms
# Speed: 4.0ms preprocess, 84.8ms inference, 23.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 fire hydrant, 6 teddy bears, 100.9ms
# Speed: 17.5ms preprocess, 100.9ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 teddy bears, 51.6ms
# Speed: 18.4ms preprocess, 51.6ms inference, 21.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 teddy bears, 126.6ms
# Speed: 20.3ms preprocess, 126.6ms inference, 22.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 teddy bears, 44.0ms
# Speed: 2.7ms preprocess, 44.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 teddy bears, 69.8ms
# Speed: 4.4ms preprocess, 69.8ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 teddy bears, 44.2ms
# Speed: 17.4ms preprocess, 44.2ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 3 teddy bears, 126.1ms
# Speed: 19.2ms preprocess, 126.1ms inference, 18.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 teddy bears, 24.1ms
# Speed: 4.4ms preprocess, 24.1ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 7 teddy bears, 73.6ms
# Speed: 15.7ms preprocess, 73.6ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 parking meter, 3 teddy bears, 26.6ms
# Speed: 5.7ms preprocess, 26.6ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 parking meter, 6 teddy bears, 118.3ms
# Speed: 21.0ms preprocess, 118.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 car, 1 parking meter, 1 teddy bear, 23.4ms
# Speed: 2.9ms preprocess, 23.4ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 traffic light, 10 teddy bears, 113.8ms
# Speed: 19.6ms preprocess, 113.8ms inference, 18.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 7 teddy bears, 71.4ms
# Speed: 5.5ms preprocess, 71.4ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 teddy bears, 29.6ms
# Speed: 6.3ms preprocess, 29.6ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 teddy bear, 104.0ms
# Speed: 19.4ms preprocess, 104.0ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 traffic light, 5 teddy bears, 23.6ms
# Speed: 3.9ms preprocess, 23.6ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 fire hydrants, 7 teddy bears, 42.6ms
# Speed: 13.1ms preprocess, 42.6ms inference, 18.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.0ms
# Speed: 17.7ms preprocess, 102.0ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.3ms
# Speed: 3.6ms preprocess, 75.3ms inference, 19.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.3ms
# Speed: 5.5ms preprocess, 61.3ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 traffic lights, 100.6ms
# Speed: 6.0ms preprocess, 100.6ms inference, 22.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 traffic lights, 73.2ms
# Speed: 16.7ms preprocess, 73.2ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 1 traffic light, 96.8ms
# Speed: 21.1ms preprocess, 96.8ms inference, 19.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 1 sports ball, 24.5ms
# Speed: 3.2ms preprocess, 24.5ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 83.2ms
# Speed: 23.7ms preprocess, 83.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 3 traffic lights, 24.5ms
# Speed: 4.1ms preprocess, 24.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 train, 1 traffic light, 24.4ms
# Speed: 3.0ms preprocess, 24.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 trains, 24.5ms
# Speed: 3.4ms preprocess, 24.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 train, 24.7ms
# Speed: 3.1ms preprocess, 24.7ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 sports ball, 29.4ms
# Speed: 5.0ms preprocess, 29.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 24.3ms
# Speed: 4.0ms preprocess, 24.3ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 126.8ms
# Speed: 17.0ms preprocess, 126.8ms inference, 17.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 traffic light, 23.4ms
# Speed: 5.3ms preprocess, 23.4ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 100.8ms
# Speed: 17.0ms preprocess, 100.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 23.7ms
# Speed: 3.7ms preprocess, 23.7ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 125.7ms
# Speed: 17.4ms preprocess, 125.7ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.8ms
# Speed: 3.4ms preprocess, 26.8ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 124.1ms
# Speed: 17.2ms preprocess, 124.1ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.8ms
# Speed: 2.9ms preprocess, 25.8ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 sports ball, 94.1ms
# Speed: 14.9ms preprocess, 94.1ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 28.2ms
# Speed: 5.1ms preprocess, 28.2ms inference, 21.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.0ms
# Speed: 16.5ms preprocess, 82.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 4.0ms preprocess, 25.4ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.5ms
# Speed: 17.1ms preprocess, 107.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 117.0ms
# Speed: 19.8ms preprocess, 117.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.4ms
# Speed: 16.5ms preprocess, 106.4ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.8ms
# Speed: 2.6ms preprocess, 81.8ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.0ms
# ...
#
# 0: 384x640 (no detections), 123.0ms
# Speed: 18.4ms preprocess, 123.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 sports ball, 108.8ms
# Speed: 5.6ms preprocess, 108.8ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 1 clock, 43.5ms
# Speed: 9.3ms preprocess, 43.5ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 1 clock, 112.8ms
# Speed: 18.3ms preprocess, 112.8ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 1 clock, 27.2ms
# Speed: 3.1ms preprocess, 27.2ms inference, 24.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 113.2ms
# Speed: 17.6ms preprocess, 113.2ms inference, 21.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 clock, 23.4ms
# Speed: 5.0ms preprocess, 23.4ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 121.8ms
# Speed: 16.7ms preprocess, 121.8ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 clock, 24.4ms
# Speed: 3.4ms preprocess, 24.4ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 112.9ms
# Speed: 16.1ms preprocess, 112.9ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 26.7ms
# Speed: 4.3ms preprocess, 26.7ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 40.0ms
# Speed: 16.2ms preprocess, 40.0ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 73.9ms
# Speed: 14.9ms preprocess, 73.9ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 25.1ms
# Speed: 3.5ms preprocess, 25.1ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 97.8ms
# Speed: 18.7ms preprocess, 97.8ms inference, 23.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 24.5ms
# Speed: 3.5ms preprocess, 24.5ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 132.3ms
# Speed: 19.5ms preprocess, 132.3ms inference, 19.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 24.2ms
# Speed: 3.9ms preprocess, 24.2ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 80.2ms
# Speed: 23.0ms preprocess, 80.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 cell phone, 24.2ms
# Speed: 3.7ms preprocess, 24.2ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 80.9ms
# Speed: 36.3ms preprocess, 80.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 26.5ms
# Speed: 4.0ms preprocess, 26.5ms inference, 21.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 128.7ms
# Speed: 20.0ms preprocess, 128.7ms inference, 23.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 23.8ms
# Speed: 3.5ms preprocess, 23.8ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 87.5ms
# Speed: 15.2ms preprocess, 87.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 scissors, 23.6ms
# Speed: 3.8ms preprocess, 23.6ms inference, 18.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 scissors, 103.1ms
# Speed: 16.4ms preprocess, 103.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 scissors, 23.7ms
# Speed: 2.7ms preprocess, 23.7ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 scissors, 100.8ms
# Speed: 18.6ms preprocess, 100.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 scissors, 24.6ms
# Speed: 2.8ms preprocess, 24.6ms inference, 19.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 scissors, 85.6ms
# Speed: 21.9ms preprocess, 85.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 24.1ms
# Speed: 3.4ms preprocess, 24.1ms inference, 18.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 93.3ms
# Speed: 19.1ms preprocess, 93.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 24.1ms
# Speed: 3.5ms preprocess, 24.1ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 95.7ms
# Speed: 16.6ms preprocess, 95.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 25.4ms
# Speed: 3.9ms preprocess, 25.4ms inference, 19.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 112.4ms
# Speed: 18.9ms preprocess, 112.4ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 24.1ms
# Speed: 4.1ms preprocess, 24.1ms inference, 19.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 82.4ms
# Speed: 22.6ms preprocess, 82.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 23.6ms
# Speed: 3.7ms preprocess, 23.6ms inference, 15.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 89.6ms
# Speed: 16.9ms preprocess, 89.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 23.6ms
# Speed: 3.1ms preprocess, 23.6ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 93.8ms
# Speed: 16.0ms preprocess, 93.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 23.8ms
# Speed: 4.3ms preprocess, 23.8ms inference, 20.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 101.3ms
# Speed: 18.2ms preprocess, 101.3ms inference, 21.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 24.5ms
# Speed: 3.6ms preprocess, 24.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 24.7ms
# Speed: 3.2ms preprocess, 24.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 24.3ms
# Speed: 3.3ms preprocess, 24.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 24.9ms
# Speed: 3.1ms preprocess, 24.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 30.5ms
# Speed: 3.1ms preprocess, 30.5ms inference, 26.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 97.1ms
# Speed: 17.2ms preprocess, 97.1ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 72.1ms
# Speed: 4.7ms preprocess, 72.1ms inference, 28.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 148.5ms
# Speed: 4.4ms preprocess, 148.5ms inference, 18.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 78.6ms
# Speed: 23.0ms preprocess, 78.6ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 29.7ms
# Speed: 4.7ms preprocess, 29.7ms inference, 27.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 119.5ms
# Speed: 18.3ms preprocess, 119.5ms inference, 26.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 23.8ms
# Speed: 3.3ms preprocess, 23.8ms inference, 18.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 127.8ms
# Speed: 20.9ms preprocess, 127.8ms inference, 19.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 92.8ms
# Speed: 5.4ms preprocess, 92.8ms inference, 19.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 54.6ms
# Speed: 17.6ms preprocess, 54.6ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 83.7ms
# Speed: 18.8ms preprocess, 83.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 92.6ms
# Speed: 3.0ms preprocess, 92.6ms inference, 19.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 91.8ms
# Speed: 15.7ms preprocess, 91.8ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 31.9ms
# Speed: 5.3ms preprocess, 31.9ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 132.9ms
# Speed: 16.2ms preprocess, 132.9ms inference, 19.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 24.6ms
# Speed: 4.5ms preprocess, 24.6ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 107.1ms
# Speed: 14.9ms preprocess, 107.1ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 78.9ms
# Speed: 5.6ms preprocess, 78.9ms inference, 18.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 116.3ms
# Speed: 15.8ms preprocess, 116.3ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 sports ball, 1 keyboard, 71.5ms
# Speed: 4.9ms preprocess, 71.5ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 83.1ms
# Speed: 19.1ms preprocess, 83.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 sports ball, 1 keyboard, 1 scissors, 30.6ms
# Speed: 14.1ms preprocess, 30.6ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 scissors, 117.3ms
# Speed: 18.6ms preprocess, 117.3ms inference, 21.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 scissors, 25.3ms
# Speed: 4.1ms preprocess, 25.3ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 scissors, 111.1ms
# Speed: 19.0ms preprocess, 111.1ms inference, 19.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 sports ball, 1 keyboard, 1 scissors, 27.2ms
# Speed: 5.4ms preprocess, 27.2ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 scissors, 129.1ms
# Speed: 17.8ms preprocess, 129.1ms inference, 19.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 1 scissors, 143.0ms
# Speed: 3.6ms preprocess, 143.0ms inference, 26.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 31.0ms
# Speed: 13.2ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 24.6ms
# Speed: 3.6ms preprocess, 24.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 24.8ms
# Speed: 3.8ms preprocess, 24.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 73.1ms
# Speed: 17.6ms preprocess, 73.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 24.4ms
# Speed: 2.6ms preprocess, 24.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 24.5ms
# Speed: 3.1ms preprocess, 24.5ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 28.6ms
# Speed: 5.8ms preprocess, 28.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 25.4ms
# Speed: 3.7ms preprocess, 25.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 25.7ms
# Speed: 3.3ms preprocess, 25.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 23.9ms
# Speed: 2.7ms preprocess, 23.9ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 98.4ms
# Speed: 16.7ms preprocess, 98.4ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 28.0ms
# Speed: 3.8ms preprocess, 28.0ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 105.4ms
# Speed: 15.0ms preprocess, 105.4ms inference, 21.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 92.5ms
# Speed: 3.7ms preprocess, 92.5ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 110.8ms
# Speed: 16.8ms preprocess, 110.8ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 64.5ms
# Speed: 6.5ms preprocess, 64.5ms inference, 25.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 88.7ms
# Speed: 24.1ms preprocess, 88.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 27.4ms
# Speed: 6.5ms preprocess, 27.4ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 32.5ms
# Speed: 13.5ms preprocess, 32.5ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 32.5ms
# Speed: 15.8ms preprocess, 32.5ms inference, 11.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 77.2ms
# Speed: 17.2ms preprocess, 77.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 38.1ms
# Speed: 15.2ms preprocess, 38.1ms inference, 20.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 119.8ms
# Speed: 30.1ms preprocess, 119.8ms inference, 20.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 25.6ms
# Speed: 5.0ms preprocess, 25.6ms inference, 19.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 104.8ms
# Speed: 16.8ms preprocess, 104.8ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 26.2ms
# Speed: 4.1ms preprocess, 26.2ms inference, 28.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 111.8ms
# Speed: 18.1ms preprocess, 111.8ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 74.7ms
# Speed: 5.1ms preprocess, 74.7ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 35.4ms
# Speed: 13.7ms preprocess, 35.4ms inference, 19.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 86.2ms
# Speed: 21.9ms preprocess, 86.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 24.1ms
# Speed: 2.7ms preprocess, 24.1ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 keyboard, 125.6ms
# Speed: 40.9ms preprocess, 125.6ms inference, 21.5ms postprocess per image at shape (1, 3, 384, 640)
# Most people in frame: 42435 with 37 persons
# Largest person in frame: 41474 with size 65412
# Smallest person in frame: 41476 with size 14
